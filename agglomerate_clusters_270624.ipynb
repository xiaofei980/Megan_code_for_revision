# %%
#### Agglomeration of communities ####
# Slightly altered version of Megan Cole's script.
# -Jannes Roelink

import pandas as pd 
import os 
from datetime import datetime 
from sklearn.cluster import AgglomerativeClustering 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Path to datafile
clus_path = 'Rphenograph_Megan_24June_output_31clusters_k115_13ct_fractions.csv'

# Get current directory and specify data path
path = os.getcwd()
data_path = path + '/Data/'

# Set output path 
output_dir = f"{data_path}/agglomerative_clustering_output/"

data = pd.read_csv(f"{clus_path}", index_col=0)

# Remove indexing information for calculations (will be added back later)
df = data.iloc[:,3:]

# Get original number of clusters
clus_num = df['cluster'].max()

df
# Out:
#         B cells  Dendritic cells  Dendritic cells CD103  Endothelium  \
# 1      0.000000         0.000000               0.000000     0.000000
# 2      0.066667         0.000000               0.000000     0.000000
# 3      0.000000         0.000000               0.000000     0.000000
# 4      0.038462         0.000000               0.000000     0.423077
# 5      0.000000         0.666667               0.000000     0.047619
# ...         ...              ...                    ...          ...
# 83029  0.000000         0.000000               0.000000     0.090909
# 83030  0.000000         0.000000               0.000000     0.272727
# 83031  0.125000         0.062500               0.125000     0.312500
# 83032  0.142857         0.000000               0.214286     0.214286
# 83033  0.000000         0.000000               0.000000     0.833333
#
#        Epithelium  Fibroblasts  Macrophages type1  Macrophages type2  \
# 1             0.0          0.0           0.062500           0.000000
# 2             0.0          0.0           0.000000           0.800000
# 3             0.0          0.0           0.000000           0.000000
# 4             0.0          0.0           0.000000           0.000000
# 5             0.0          0.0           0.000000           0.190476
# ...           ...          ...                ...                ...
# 83029         0.0          0.0           0.000000           0.181818
# 83030         0.0          0.0           0.181818           0.000000
# 83031         0.0          0.0           0.062500           0.000000
# 83032         0.0          0.0           0.071429           0.000000
# 83033         0.0          0.0           0.000000           0.000000
#
#        Neutrophils  T cells CD4  T cells CD8  T reg cells    Tumour  cluster
# 1         0.000000     0.000000     0.062500          0.0  0.875000        1
# 2         0.000000     0.066667     0.066667          0.0  0.000000        2
# 3         0.000000     0.000000     0.153846          0.0  0.846154        1
# 4         0.346154     0.038462     0.115385          0.0  0.038462        3
# 5         0.000000     0.000000     0.095238          0.0  0.000000        4
# ...            ...          ...          ...          ...       ...      ...
# 83029     0.000000     0.181818     0.181818          0.0  0.363636        8
# 83030     0.000000     0.000000     0.181818          0.0  0.363636        9
# 83031     0.250000     0.062500     0.000000          0.0  0.000000        3
# 83032     0.071429     0.214286     0.000000          0.0  0.071429        2
# 83033     0.000000     0.166667     0.000000          0.0  0.000000       11
#
# [83033 rows x 14 columns]

# %%
# Create average_neighbours (centroids of all cells in a cluster based on the fractions)
centroid_noclus = df.groupby('cluster').mean()
centroids = centroid_noclus.reset_index()
# Look at first few centroids
centroid_noclus.head()
# Out:
#           B cells  Dendritic cells  Dendritic cells CD103  Endothelium  \
# cluster
# 1        0.001988         0.019817               0.001917     0.010107
# 2        0.008161         0.036077               0.023041     0.049599
# 3        0.049823         0.010967               0.011922     0.523979
# 4        0.007995         0.322620               0.009576     0.087777
# 5        0.138138         0.019407               0.016897     0.138340
#
#          Epithelium  Fibroblasts  Macrophages type1  Macrophages type2  \
# cluster
# 1          0.000975     0.003138           0.005905           0.029784
# 2          0.002246     0.042396           0.118003           0.578763
# 3          0.012604     0.008869           0.162243           0.012310
# 4          0.002652     0.022823           0.060727           0.187042
# 5          0.015751     0.043022           0.040688           0.020081
#
#          Neutrophils  T cells CD4  T cells CD8  T reg cells    Tumour
# cluster
# 1           0.002072     0.001032     0.051794     0.000000  0.871469
# 2           0.009522     0.078189     0.023813     0.003267  0.026921
# 3           0.089208     0.046220     0.032025     0.000582  0.039247
# 4           0.007790     0.099831     0.060791     0.005935  0.124441
# 5           0.021130     0.375910     0.076142     0.051295  0.043199

# %%
#### Agglomerative clustering function ####

def agglomerative_clustering(average_neighbours, avg_noCluster, agglomerate_to):
    
    # Agglomerative clustering to chosen number of communities
    ac1 = AgglomerativeClustering(linkage = 'average', n_clusters = agglomerate_to)
    agglomerate1 = pd.DataFrame(ac1.fit_predict(avg_noCluster))
    agglomerate1.columns = [f"agglomerateto_{agglomerate_to}"]
    agglomerate1[f"agglomerateto_{agglomerate_to}"] += 1
    # Add agglomerated data to average neighbours 
    average_neighbours = average_neighbours.join(agglomerate1)
   
    print(list(average_neighbours))
    
    # Save data with added columns 
    average_neighbours.to_csv(f"{output_dir}aggloclus_clus{agglomerate_to}.csv", index = False)
    print('dataset saved')

    return pd.DataFrame(average_neighbours)

# %%
# agglomerate to 18 communities
average_neighbours18= agglomerative_clustering(centroids, centroid_noclus, 18)
average_neighbours18
# Out:
# ['cluster', 'B cells', 'Dendritic cells', 'Dendritic cells CD103', 'Endothelium', 'Epithelium', 'Fibroblasts', 'Macrophages type1', 'Macrophages type2', 'Neutrophils', 'T cells CD4', 'T cells CD8', 'T reg cells', 'Tumour', 'agglomerateto_19']
# dataset saved
#     cluster   B cells  Dendritic cells  Dendritic cells CD103  Endothelium  \
# 0         1  0.001988         0.019817               0.001917     0.010107
# 1         2  0.008161         0.036077               0.023041     0.049599
# 2         3  0.049823         0.010967               0.011922     0.523979
# 3         4  0.007995         0.322620               0.009576     0.087777
# 4         5  0.138138         0.019407               0.016897     0.138340
# 5         6  0.019226         0.002925               0.002906     0.585506
# 6         7  0.013139         0.008654               0.003657     0.119830
# 7         8  0.010539         0.071793               0.010968     0.059778
# 8         9  0.029827         0.021383               0.013516     0.218726
# 9        10  0.004248         0.007989               0.004114     0.017807
# 10       11  0.015076         0.003443               0.002105     0.787494
# 11       12  0.039968         0.022076               0.008910     0.066081
# 12       13  0.002290         0.002682               0.003332     0.004438
# 13       14  0.021602         0.008327               0.018773     0.461235
# 14       15  0.033358         0.007026               0.010819     0.043649
# 15       16  0.002021         0.002772               0.001836     0.001008
# 16       17  0.010700         0.012135               0.022347     0.026471
# 17       18  0.000794         0.001587               0.002227     0.000000
# 18       19  0.000000         0.000000               0.003128     0.000000
# 19       20  0.092719         0.004997               0.000689     0.006484
# 20       21  0.034540         0.004791               0.007082     0.382733
# 21       22  0.000000         0.000000               0.000000     0.000000
# 22       23  0.000196         0.000234               0.001269     0.000000
# 23       24  0.000000         0.000000               0.002428     0.000000
# 24       25  0.000000         0.000000               0.000509     0.000000
# 25       26  0.006924         0.001400               0.000732     0.028462
# 26       27  0.013645         0.003688               0.003436     0.102392
# 27       28  0.001580         0.001593               0.003673     0.026696
# 28       29  0.002962         0.000974               0.000000     0.000035
# 29       30  0.000000         0.000000               0.000000     0.065451
# 30       31  0.000000         0.000000               0.000000     0.000000
#
#     Epithelium  Fibroblasts  Macrophages type1  Macrophages type2  \
# 0     0.000975     0.003138           0.005905           0.029784
# 1     0.002246     0.042396           0.118003           0.578763
# 6                 18
# 7                  1
# 8                  6
# 9                 19
# 10                11
# 11                 8
# 12                 2
# 13                10
# 14                15
# 15                 5
# 16                 1
# 17                 4
# 18                 2
# 19                 2
# 20                 9
# 21                 2
# 22                 4
# 23                 2
# 24                 2
# 25                 7
# 26                 3
# 27                 2
# 28                 2
# 29                 2
# 30                 2

# %%
# Add agglomerated clusters to original data and save to output file. 
data_aggl = pd.merge(data,average_neighbours18[['cluster', 'agglomerateto_18']], on='cluster', how='inner')
# Rename the old cluster column to keep track of original number of clusters
data_aggl = data_aggl.rename(columns={'cluster':f'cluster{clus_num}'})
data_aggl.to_csv(f'{output_dir}celldata_agglo_clus_{clus_num}to18_240624.csv')
data_aggl
# Out:
#             ROI_ID  source_ID     source_cluster   B cells  Dendritic cells  \
# 0      01_MRTX+PD1      Cell1        T cells CD8  0.000000         0.000000
# 1      01_MRTX+PD1     Cell10  Macrophages type2  0.066667         0.000000
# 2      01_MRTX+PD1    Cell100             Tumour  0.000000         0.000000
# 3      01_MRTX+PD1   Cell1000        T cells CD4  0.038462         0.000000
# 4      01_MRTX+PD1  Cell10000    Dendritic cells  0.000000         0.666667
# ...            ...        ...                ...       ...              ...
# 83028  08_MRTX+PD1  Cell83031        Fibroblasts  0.000000         0.000000
# 83029  08_MRTX+PD1  Cell83032  Macrophages type1  0.000000         0.000000
# 83030  08_MRTX+PD1  Cell83033             Tumour  0.125000         0.062500
# 83031  08_MRTX+PD1  Cell83034             Tumour  0.142857         0.000000
# 83032  08_MRTX+PD1  Cell83035        Endothelium  0.000000         0.000000
#
#        Dendritic cells CD103  Endothelium  Epithelium  Fibroblasts  \
# 0                   0.000000     0.000000         0.0          0.0
# 1                   0.000000     0.000000         0.0          0.0
# 2                   0.000000     0.000000         0.0          0.0
# 3                   0.000000     0.423077         0.0          0.0
# 4                   0.000000     0.047619         0.0          0.0
# ...                      ...          ...         ...          ...
# 83028               0.000000     0.090909         0.0          0.0
# 83029               0.000000     0.272727         0.0          0.0
# 83030               0.125000     0.312500         0.0          0.0
# 83031               0.214286     0.214286         0.0          0.0
# 83032               0.000000     0.833333         0.0          0.0
#
#        Macrophages type1  Macrophages type2  Neutrophils  T cells CD4  \
# 0               0.062500           0.000000     0.000000     0.000000
# 1               0.000000           0.800000     0.000000     0.066667
# 2               0.000000           0.000000     0.000000     0.000000
# 3               0.000000           0.000000     0.346154     0.038462
# 4               0.000000           0.190476     0.000000     0.000000
# ...                  ...                ...          ...          ...
# 83028           0.000000           0.181818     0.000000     0.181818
# 83029           0.181818           0.000000     0.000000     0.000000
# 83030           0.062500           0.000000     0.250000     0.062500
# 83031           0.071429           0.000000     0.071429     0.214286
# 83032           0.000000           0.000000     0.000000     0.166667
#
#        T cells CD8  T reg cells    Tumour  cluster31  agglomerateto_19
# 0         0.062500          0.0  0.875000          1                 2
# 1         0.066667          0.0  0.000000          2                17
# 2         0.153846          0.0  0.846154          1                 2
# 3         0.115385          0.0  0.038462          3                16
# 4         0.095238          0.0  0.000000          4                14
# ...            ...          ...       ...        ...               ...
# 83028     0.181818          0.0  0.363636          8                 1
# 83029     0.181818          0.0  0.363636          9                 6
# 83030     0.000000          0.0  0.000000          3                16
# 83031     0.000000          0.0  0.071429          2                17
# 83032     0.000000          0.0  0.000000         11                11
#
# [83033 rows x 18 columns]
